# %% [markdown]
# <a href="https://colab.research.google.com/github/Astromax0102/fire-model/blob/main/Train_YOLO_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Train YOLO Models in Google Colab
# **Author:** Evan Juras, [EJ Technology Consultants](https://ejtech.io)
#
# **Last updated:** January 3, 2025
#
# **GitHub:** [Train and Deploy YOLO Models](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models)
#
# # Introduction
#
# This notebook uses [Ultralytics](https://docs.ultralytics.com/) to train YOLO11, YOLOv8, or YOLOv5 object detection models with a custom dataset. At the end of this Colab, you'll have a custom YOLO model that you can run on your PC, phone, or edge device like the Raspberry Pi.
#
# <p align=center>
# <img src="https://s3.us-west-1.amazonaws.com/evanjuras.com/img/yolo-model-demo.gif" height="360"><br>
# <i>Custom YOLO candy detection model in action!</i>
# </p>
#
# I created a YouTube video that walks through this guide step by step. I recommend following along with the video while working through this notebook.
#
# <p align=center>
# <a href="https://youtu.be/r0RspiLG260" target="_blank"><img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/Train_YOLO_Thumbnail2.png" height="240"><br>
# <i>Click here to go to the video!</i></a>
# </p>
#
# **Important note: This notebook will be continuously updated to make sure it works with newer versions of Ultralytics and YOLO. If you see any differences between the YouTube video and this notebook, always follow the notebook!**
#
# ### Working in Colab
# Colab provides a virtual machine in your browser complete with a Linux OS, filesystem, Python environment, and best of all, a free GPU. We'll install PyTorch and Ultralytics in this environment and use it to train our model. Simply click the Play button on sections of code in this notebook to execute them on the virtual machine.
#
# ### Navigation
# To navigate this notebook, use the table of contents in the left sidebar to jump from section to section.

# %% [markdown]
# **Verify NVIDIA GPU Availability**
#
# Make sure you're using a GPU-equipped machine by going to "Runtime" -> "Change runtime type" in the top menu bar, and then selecting one of the GPU options in the Hardware accelerator section. Click Play on the following code block to verify that the NVIDIA GPU is present and ready for training.

# %%
# !nvidia-smi

# %% [markdown]
# #1.&nbsp;Gather and Label Training Images

# %% [markdown]
# Before we start training, we need to gather and label images that will be used for training the object detection model. A good starting point for a proof-of-concept model is 200 images. The training images should have random objects in the image along with the desired objects, and should have a variety of backgrounds and lighting conditions.
#
# There are a couple options for gathering images:
#
#
# *   Build a custom dataset by taking your own pictures of the objects and labeling them (this typically results in the best performance)
# *   Find a pre-made dataset from sources like [Roboflow Universe](), [Kaggle](), or [Google Images V7]()
#
#
# If you want to build your own dataset, there are several tools available for labeling images. One good option is [Label Studio](https://labelstud.io/?utm_source=youtube&utm_medium=video&utm_campaign=edjeelectronics), a free and open-source labeling tool that has a simple workflow while providing capabilities for more advanced features. My YouTube video that walks through this notebook (link to be added soon) shows how to label images with Label Studio.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/label-studio-example.PNG" height="380"><br>
# <i>Example of a candy image labeled with Label Studio.</i>
# </p>
#
# If you used Label Studio to label and export the images, they'll be exported in a `project.zip` file that contains the following:
#
# - An `images` folder containing the images
# - A `labels` folder containing the labels in YOLO annotation format
# - A `classes.txt` labelmap file that contains all the classes
# - A `notes.json` file that contains info specific to Label Studio (this file can be ignored)
#
# If you obtained your dataset from another source (like Roboflow Universe) or used another tool to label your dataset, make sure the files are organized in the same folder structure.
#
# <p align=center>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/zipped-data-example.png" height=""><br>
# <i>Organize your data in the folders shown here. See my <a href="https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip">Candy Detection Dataset</a> for an example.</i>
# </p>
#
# Once you've got your dataset built, put into the file structure shown above, and zipped into `data.zip`, you're ready to move on to the next step.

# %% [markdown]
# # 2.&nbsp;Upload Image Dataset and Prepare Training Data

# %% [markdown]
# Next, we'll upload our dataset and prepare it for training with YOLO. We'll split the dataset into train and validation folders, and we'll automatically generate the configuration file for training the model.

# %% [markdown]
# ## 2.1 Upload images
#
# First, we need to upload the dataset to Colab. Here are a few options for moving the `data.zip` folder into this Colab instance.

# %% [markdown]
# **Option 1. Upload through Google Colab**
#
# Upload the `data.zip` file to the Google Colab instance by clicking the "Files" icon on the left hand side of the browser, and then the "Upload to session storage" icon. Select the zip folder to upload it.
#
# <p>
# <br>
# <img src="https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/doc/upload-colab-files.png" height="240">
# </p>

# %% [markdown]
# **Option 2. Copy from Google Drive**
#
# You can also upload your images to your personal Google Drive, mount the drive on this Colab session, and copy them over to the Colab filesystem. This option works well if you want to upload the images beforehand so you don't have to wait for them to upload each time you restart this Colab. If you have more than 50MB worth of images, I recommend using this option.
#
# First, upload the `data.zip` file to your Google Drive, and make note of the folder you uploaded them to. Replace `MyDrive/path/to/data.zip` with the path to your zip file. (For example, I uploaded the zip file to folder called "candy-dataset1", so I would use `MyDrive/candy-dataset1/data.zip` for the path). Then, run the following block of code to mount your Google Drive to this Colab session and copy the folder to this filesystem.

# %%
from google.colab import drive
drive.mount('/content/gdrive')

# !cp /content/gdrive/MyDrive/path/to/data.zip /content

# %% [markdown]
# **Option 3. Use my candy detection or coin detection dataset**
#
# If you just want to test the process on a pre-made dataset, you can use one of my datasets:
#
# *   [Candy image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_14DEC24.zip), which contains 162 pictures of popular candies (Skittles, Snickers, etc)
# *   [Coin image dataset](https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip), which contains 750 pictures of US coins (pennies, dimes, nickels, and quarters)
#
# Download one of the datasets by running the following code block. I'll use the candy detection dataset as the example for the rest of the notebook.

# %%
# To use my one of pre-made dataset instead of your own custom dataset, download it here (control which dataset is downloaded by commenting out either line)
# !wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/candy_data_06JAN25.zip # Candy dataset
#!wget -O /content/data.zip https://s3.us-west-1.amazonaws.com/evanjuras.com/resources/YOLO_coin_data_12DEC30.zip # Coin dataset

# %% [markdown]
# ## 2.2 Split images into train and validation folders

# %% [markdown]
# At this point, whether you used Option 1, 2, or 3, you should be able to click the folder icon on the left and see your `data.zip` file in the list of files. Next, we'll unzip `data.zip` and create some folders to hold the images. Run the following code block to unzip the data.

# %%
# Unzip images to a custom data folder
# !unzip -q /content/data.zip -d /content/custom_data

# %% [markdown]
# Ultralytics requires a particular folder structure to store training data for models. Ultralytics requires a particular folder structure to store training data for models. The root folder is named “data”. Inside, there are two main folders:
#
# *   **Train**: These are the actual images used to train the model. In one epoch of training, every image in the train set is passed into the neural network. The training algorithm adjusts the network weights to fit the data in the images.
#
#
# *   **Validation**: These images are used to check the model's performance at the end of each training epoch.
#
# In each of these folders is a “images” folder and a “labels” folder, which hold the image files and annotation files respectively.

# %% [markdown]
# I wrote a Python script that will automatically create the required folder structure and randomly move 90% of dataset to the "train" folder and 10% to the "validation" folder. Run the following code block to download and execute the scrpt.

# %%
# !wget -O /content/train_val_split.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/utils/train_val_split.py

# TO DO: Improve robustness of train_val_split.py script so it can handle nested data folders, etc
# !python train_val_split.py --datapath="/content/custom_data" --train_pct=0.9

# %% [markdown]
# # 3.&nbsp;Install Requirements (Ultralytics)
#
# Next, we'll install the Ultralytics library in this Google Colab instance. This Python library will be used to train the YOLO model.

# %%
# !pip install ultralytics

# %% [markdown]
# # 4.&nbsp;Configure Training

# %% [markdown]
# There's one last step before we can run training: we need to create the Ultralytics training configuration YAML file. This file specifies the location of your train and validation data, and it also defines the model's classes. An example configuration file model is available [here](https://github.com/ultralytics/ultralytics/blob/main/ultralytics/cfg/datasets/coco128.yaml).
#
# Run the code block below to automatically generate a `data.yaml` configuration file. Make sure you have a labelmap file located at `custom_data/classes.txt`. If you used Label Studio or one of my pre-made datasets, it should already be present. If you assembled the dataset another way, you may have to manually create the `classes.txt` file (see [here](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/doc/classes.txt) for an example of how it's formatted).

# %%
# Python function to automatically create data.yaml config file
# 1. Reads "classes.txt" file to get list of class names
# 2. Creates data dictionary with correct paths to folders, number of classes, and names of classes
# 3. Writes data in YAML format to data.yaml

import yaml
import os

def create_data_yaml(path_to_classes_txt, path_to_data_yaml):

  # Read class.txt to get class names
  if not os.path.exists(path_to_classes_txt):
    print(f'classes.txt file not found! Please create a classes.txt labelmap and move it to {path_to_classes_txt}')
    return
  with open(path_to_classes_txt, 'r') as f:
    classes = []
    for line in f.readlines():
      if len(line.strip()) == 0: continue
      classes.append(line.strip())
  number_of_classes = len(classes)

  # Create data dictionary
  data = {
      'path': '/content/data',
      'train': 'train/images',
      'val': 'validation/images',
      'nc': number_of_classes,
      'names': classes
  }

  # Write data to YAML file
  with open(path_to_data_yaml, 'w') as f:
    yaml.dump(data, f, sort_keys=False)
  print(f'Created config file at {path_to_data_yaml}')

  return

# Define path to classes.txt and run function
path_to_classes_txt = '/content/custom_data/classes.txt'
path_to_data_yaml = '/content/data.yaml'

create_data_yaml(path_to_classes_txt, path_to_data_yaml)

print('\nFile contents:\n')
# !cat /content/data.yaml

# %% [markdown]
# # 5.&nbsp;Train Model

# %% [markdown]
# ## 5.1 Training Parameters
# Now that the data is organized and the config file is created, we're ready to start training! First, there are a few important parameters to decide on. Visit my article on [Training YOLO Models Locally](https://www.ejtech.io/learn/train-yolo-models) to learn more about these parameters and how to choose them.
#
# **Model architecture & size (`model`):**
#
# There are several YOLO11 models sizes available to train, including `yolo11n.pt`, `yolo11s.pt`, `yolo11m.pt`, `yolo11l.pt`, and `yolo11xl.pt`. Larger models run slower but have higher accuracy, while smaller models run faster but have lower accuracy. I made a brief YouTube video that compares performance of different YOLO models on a Raspberry Pi 5 and a laptop with a RTX 4050 GPU, [check it out here to get a sense of their speed accuracy](https://youtu.be/_WKS4E9SmkA). If you aren't sure which model size to use, `yolo11s.pt` is a good starting point.
#
# You can also train YOLOv8 or YOLOv5 models by substituting `yolo11` for `yolov8` or `yolov5`.
#
#
# **Number of epochs (`epochs`)**
#
# In machine learning, one “epoch” is one single pass through the full training dataset. Setting the number of epochs dictates how long the model will train for. The best amount of epochs to use depends on the size of the dataset and the model architecture. If your dataset has less than 200 images, a good starting point is 60 epochs. If your dataset has more than 200 images, a good starting point is 40 epochs.
#
#
# **Resolution (`imgsz`)**
#
# Resolution has a large impact on the speed and accuracy of the model: a lower resolution model will have higher speed but less accuracy. YOLO models are typically trained and inferenced at a 640x640 resolution. However, if you want your model to run faster or know you will be working with low-resolution images, try using a lower resolution like 480x480.

# %% [markdown]
# ## 5.2 Run Training!

# %% [markdown]
# Run the following code block to begin training. If you want to use a different model, number of epochs, or resolution, change `model`, `epochs`, or `imgsz`.

# %%
# !yolo detect train data=/content/data.yaml model=yolov8n.pt epochs=100 imgsz=640
# Out:
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# engine/trainer: task=detect, mode=train, model=yolov8n.pt, data=/content/data.yaml, epochs=100, time=None, patience=100, batch=16, imgsz=640, save=True, save_period=-1, cache=False, device=None, workers=8, project=None, name=train3, exist_ok=False, pretrained=True, optimizer=auto, verbose=True, seed=0, deterministic=True, single_cls=False, rect=False, cos_lr=False, close_mosaic=10, resume=False, amp=True, fraction=1.0, profile=False, freeze=None, multi_scale=False, overlap_mask=True, mask_ratio=4, dropout=0.0, val=True, split=val, save_json=False, save_hybrid=False, conf=None, iou=0.7, max_det=300, half=False, dnn=False, plots=True, source=None, vid_stride=1, stream_buffer=False, visualize=False, augment=False, agnostic_nms=False, classes=None, retina_masks=False, embed=None, show=False, save_frames=False, save_txt=False, save_conf=False, save_crop=False, show_labels=True, show_conf=True, show_boxes=True, line_width=None, format=torchscript, keras=False, optimize=False, int8=False, dynamic=False, simplify=True, opset=None, workspace=None, nms=False, lr0=0.01, lrf=0.01, momentum=0.937, weight_decay=0.0005, warmup_epochs=3.0, warmup_momentum=0.8, warmup_bias_lr=0.1, box=7.5, cls=0.5, dfl=1.5, pose=12.0, kobj=1.0, nbs=64, hsv_h=0.015, hsv_s=0.7, hsv_v=0.4, degrees=0.0, translate=0.1, scale=0.5, shear=0.0, perspective=0.0, flipud=0.0, fliplr=0.5, bgr=0.0, mosaic=1.0, mixup=0.0, copy_paste=0.0, copy_paste_mode=flip, auto_augment=randaugment, erasing=0.4, crop_fraction=1.0, cfg=None, tracker=botsort.yaml, save_dir=runs/detect/train3
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1742971234.887488   21529 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1742971234.894521   21529 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# Overriding model.yaml nc=80 with nc=1
#
#                    from  n    params  module                                       arguments
#   0                  -1  1       464  ultralytics.nn.modules.conv.Conv             [3, 16, 3, 2]
#   1                  -1  1      4672  ultralytics.nn.modules.conv.Conv             [16, 32, 3, 2]
#   2                  -1  1      7360  ultralytics.nn.modules.block.C2f             [32, 32, 1, True]
#   3                  -1  1     18560  ultralytics.nn.modules.conv.Conv             [32, 64, 3, 2]
#   4                  -1  2     49664  ultralytics.nn.modules.block.C2f             [64, 64, 2, True]
#   5                  -1  1     73984  ultralytics.nn.modules.conv.Conv             [64, 128, 3, 2]
#   6                  -1  2    197632  ultralytics.nn.modules.block.C2f             [128, 128, 2, True]
#   7                  -1  1    295424  ultralytics.nn.modules.conv.Conv             [128, 256, 3, 2]
#   8                  -1  1    460288  ultralytics.nn.modules.block.C2f             [256, 256, 1, True]
#   9                  -1  1    164608  ultralytics.nn.modules.block.SPPF            [256, 256, 5]
#  10                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  11             [-1, 6]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  12                  -1  1    148224  ultralytics.nn.modules.block.C2f             [384, 128, 1]
#  13                  -1  1         0  torch.nn.modules.upsampling.Upsample         [None, 2, 'nearest']
#  14             [-1, 4]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  15                  -1  1     37248  ultralytics.nn.modules.block.C2f             [192, 64, 1]
#  16                  -1  1     36992  ultralytics.nn.modules.conv.Conv             [64, 64, 3, 2]
#  17            [-1, 12]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  18                  -1  1    123648  ultralytics.nn.modules.block.C2f             [192, 128, 1]
#  19                  -1  1    147712  ultralytics.nn.modules.conv.Conv             [128, 128, 3, 2]
#  20             [-1, 9]  1         0  ultralytics.nn.modules.conv.Concat           [1]
#  21                  -1  1    493056  ultralytics.nn.modules.block.C2f             [384, 256, 1]
#  22        [15, 18, 21]  1    751507  ultralytics.nn.modules.head.Detect           [1, [64, 128, 256]]
# Model summary: 129 layers, 3,011,043 parameters, 3,011,027 gradients, 8.2 GFLOPs
#
# Transferred 319/355 items from pretrained weights
# TensorBoard: Start with 'tensorboard --logdir runs/detect/train3', view at http://localhost:6006/
# Freezing layer 'model.22.dfl.conv.weight'
# AMP: running Automatic Mixed Precision (AMP) checks...
# AMP: checks passed ✅
# train: Scanning /content/data/train/labels... 1159 images, 2717 backgrounds, 592 corrupt: 100% 3876/3876 [00:00<00:00, 4016.68it/s]
# train: WARNING ⚠️ /content/data/train/images/large_-10-_jpg.rf.22f885b9692c259bdd7150004dbf627e.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1000-_jpg.rf.ead25cc471cb0d28d8696ea5ffb09c41.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1003-_jpg.rf.6116225c4c52b57ae7dd9b1b6b51c3c8.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1005-_jpg.rf.79e572d302cdd9660e251b124b3dc485.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1006-_jpg.rf.82ec978214cb02e1d74bc1c52f9cd2b3.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1007-_jpg.rf.65801d9caeecd0f7f7767d0a80828ebc.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1008-_jpg.rf.8097995e2ffe7e661862aa12f6c17582.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1009-_jpg.rf.dca3cdc3a1d8f4e53737cfcbbfa6d54d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1010-_jpg.rf.4aa11e5844b15a5205421da98c62204c.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1011-_jpg.rf.8fa292488f24151800d461405eac8c37.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1013-_jpg.rf.84ca876a7d25da77386fac263e219351.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1015-_jpg.rf.82c0f427f9e58165e7d68ec4f65f0790.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1018-_jpg.rf.ec3c68c2bcb1bf4bb81fb98bd7269efb.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-102-_jpg.rf.279ed0da430b8afe28ab4a3eb0124ad1.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1021-_jpg.rf.5b04f1769cf921762713882fd8baa207.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1022-_jpg.rf.a3b1122f250329527e5bd38eae79f630.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1023-_jpg.rf.dab41cca3fb5495f2b723fde1795d87a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1024-_jpg.rf.7d4dd3c17511a338a8fc29aec346ba02.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1028-_jpg.rf.e35998936398d082fdfc92a1e67bd24c.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1029-_jpg.rf.2a433ef38ebe68c8bc2874cc13800038.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-103-_jpg.rf.79c9c66424ec3d44fd4c6dac5508555d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1030-_jpg.rf.c937a3d96e1039e8278e5845ae45b4e8.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1031-_jpg.rf.23325f57f2de45f2df6b40096e30f773.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1032-_jpg.rf.275a093f51a7c1af6f8642e007b1ca21.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1033-_jpg.rf.d0b07e66e617632d2d61d8d46c948040.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1034-_jpg.rf.4be6fea1845a3b8380e39b81c331659d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1035-_jpg.rf.74ebc3822b2d69e432b152e5f623f717.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1036-_jpg.rf.fdf758ecee27db79e6f986f3a71e3249.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1037-_jpg.rf.318286d444a5a4a5725871ec5cab71a3.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1040-_jpg.rf.bd47ff3169b0dc06c5d0e375e07a6978.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1041-_jpg.rf.d90169594f5879dffe388aed12a8187a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1042-_jpg.rf.90b0b1086239a5ef8e621765d31232a9.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1043-_jpg.rf.08291a4cdfaf3bc26e7e2877066949b5.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1050-_jpg.rf.49d5bc81e83a431796c79719476bcfec.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1051-_jpg.rf.f5229b85dbab00fbc10834c5bb5cdf21.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1052-_jpg.rf.5985850bc164d7bae02af0d9a77a8b82.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1054-_jpg.rf.8de1f746a3e9aea0545a1655850f6582.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1055-_jpg.rf.cc04bb4ccc0afad5c5cb3e65c58a0d3d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1056-_jpg.rf.a153d37737a9a7438fc019a9ce34a96f.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1058-_jpg.rf.0fe50b8c66f5763928ca1ed0dea7a4a8.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1059-_jpg.rf.a106f23de7059a172baa50cee957d5ac.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-106-_jpg.rf.5a71ca0318bb708f406e4b39a9d9470a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1060-_jpg.rf.3e26d498a492e0d5921688341f1ed3ea.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1061-_jpg.rf.7c0d22c5e3a2c7c5de3efa5ef54dbc4c.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1062-_jpg.rf.771df63594126a013c65cd635c4f6cf6.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1063-_jpg.rf.d408e246ad26655d68f6301f0a776baf.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1065-_jpg.rf.f1ccc40791493adff80cdbb641f9a92e.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1066-_jpg.rf.ef2c4a31765b659c63104ed21efc5c1c.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1068-_jpg.rf.85697fe097f8e56b8c26f32b6469f021.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1069-_jpg.rf.394390300e8df70f64cf85df9763c8ec.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-107-_jpg.rf.d644ff163f04a75396d3e15b4c0e4b55.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1071-_jpg.rf.907d6e0e65a40a9b0ec19a43d34cb2db.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1072-_jpg.rf.2fa38cb6e418079b1f815370e6d66804.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1073-_jpg.rf.8cbd517e0a803259b3e635ae5fd2e6e6.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1074-_jpg.rf.3936c87ed93aa0ef97129300d3a1002f.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-108-_jpg.rf.9cfa95dfefaaecfbad09e94d927c594b.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1086-_jpg.rf.25158559766b5e6e6a51ff7a56593b76.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1087-_jpg.rf.8404e9909185bc7e8ef0392c6d10367d.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1088-_jpg.rf.e9bc47f38c55852e938006b51d38bdc7.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1089-_jpg.rf.101c6d0ff1ea64eae19e204f2fded6a6.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-109-_jpg.rf.9e0f3a396c5e40b61cd4a113cd8123fd.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1090-_jpg.rf.ab7805abf53f7bff226b5963998fa301.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1092-_jpg.rf.456c1a50f4db9da18188720891d4194b.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1093-_jpg.rf.1de1bff8e6f75b3655fbc64535cfec25.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1095-_jpg.rf.fc6ce6de970792d8231a5dda46ee64bf.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1096-_jpg.rf.5f9233b51b6e55de7ce367d55a2d7aa0.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1097-_jpg.rf.2b9402db970a2c49f856e6e83af7da2d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1099-_jpg.rf.b5e3fe0a26ac96651178c208164d8067.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-110-_jpg.rf.a944c6447ae3b3b618fc7eab7e2ae616.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1101-_jpg.rf.f93913f68df44beb5e7fba4b3f5ed7c6.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1102-_jpg.rf.dc53ae793001a659eca877d00b98d7ea.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1103-_jpg.rf.07607c6c72d6488fb2c9af29540c3387.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1105-_jpg.rf.61357173658cae22b488548a0a75bdfa.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1107-_jpg.rf.c1d0e8255f04e5fe52d1775b02a49f8b.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1108-_jpg.rf.f3c8e8ee98278c3a9e01ebf4e71cba25.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1109-_jpg.rf.99b38c910ded60fed9480cef01dc6eb0.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-111-_jpg.rf.eb73d373ef39729da25dbf317dadde97.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1111-_jpg.rf.c842b02f7059078a53f3c6c2b25961c7.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1112-_jpg.rf.0b7309ef00fb3ff42d2d21dfbf3847b5.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1113-_jpg.rf.70422570cc948d0565828931cd041758.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1115-_jpg.rf.8cbad75f48ce8eb321cf3f3ae38cf865.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1116-_jpg.rf.f148f13d6897dac7563b33355a6a4e5f.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1117-_jpg.rf.bfa991c4948188bfb477a44dfa542ebf.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1119-_jpg.rf.9a9d8734d9a1ccaf40b89218a0b57b73.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1121-_jpg.rf.3d1fb7096d653d764788a7644437a07a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1124-_jpg.rf.63f0f7ddbf779d42511ffec266df63dc.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1125-_jpg.rf.eb0071e18c12a5fb4ba1d8638ca4c92d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1126-_jpg.rf.a0b41f7c22d0790b3eb45e3ec1f4b599.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1127-_jpg.rf.140380bcaa21b49caa4b9fc8ce1241e1.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1128-_jpg.rf.2037d768e44a827f9fcf1107c80a6f64.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-113-_jpg.rf.79b9f22f7257cea5389fa1413f92a9c4.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1133-_jpg.rf.77141a54302f973694ac579e7c2bab0d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1134-_jpg.rf.2d7650497e8f547a03a9d0a3e99bbee1.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1135-_jpg.rf.859f7e9ee4326af598dd914d9fb5f053.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1136-_jpg.rf.39e22e23fc35d3db963750f47d0ad2cb.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1137-_jpg.rf.f1a7605529b79f2e2d3ce28f45d6b714.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1138-_jpg.rf.a2d1a2684b58cf422915694e7d9ed004.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1139-_jpg.rf.a6d250162d11f917f944691066b5017c.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-114-_jpg.rf.fe8ec1c9582350b926f0cb3c98e00e31.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1140-_jpg.rf.b31d18ffc4a0919e830493ef6d34e75a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1141-_jpg.rf.a73a804665ca453d0eebe136b7da001a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1142-_jpg.rf.90b652efb00ec59ffd40cef7deebcd09.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1143-_jpg.rf.92f2b0198e26947fc58b24e6df554fe7.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1144-_jpg.rf.785fe877f31475734d2cd773e948ad97.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1145-_jpg.rf.1a3a747b6c1006c98b4581d6d6b19f31.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1146-_jpg.rf.aaef99c69418008bae93521ec4932c78.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1147-_jpg.rf.5427c46ea02c9ece110e96c0ade3613f.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1148-_jpg.rf.d868c119e16d89c549034498ef36dd46.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1149-_jpg.rf.aad55247e99e93deda528c80adf47bc0.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-115-_jpg.rf.bb445794c51abe0d2a7c51031292a557.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1150-_jpg.rf.d1fdb44b49dbaec2573ed8416b8db9bc.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1151-_jpg.rf.1f756fc44a0004519a28db90867c9705.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1152-_jpg.rf.52702ff8dd3f28b62cd15949f8ae122d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1153-_jpg.rf.5edd0db9370e9c3b947774a64d284271.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1154-_jpg.rf.4c2c97792dbabd33a475286f633243df.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1155-_jpg.rf.7ec6482cfbe28b7e86c72a8d8ab630d8.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1156-_jpg.rf.f06aa86f611ec5f5ca922e179e6f9dcd.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1157-_jpg.rf.6c6fbff3e761ba37bd922946818079b3.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1158-_jpg.rf.108182d8b9a3236affa00f8887613562.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1159-_jpg.rf.3394b9a2f43a70514ae24bc9fd150420.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-116-_jpg.rf.dfbd8994bbe5ca1181edf92e9a86d244.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1160-_jpg.rf.76bebb1b6a48bf2b19d802aefdb1eea5.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1161-_jpg.rf.b52c4292edb1cd71c441b34cce1785f4.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1165-_jpg.rf.10ca86ce008ad4e1f061f9d9bc33c837.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-117-_jpg.rf.21a510bfdfa84666f1c154627ee23e2e.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-12-_jpg.rf.dcb8d73ee85446e636cfe5be51c6302a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-120-_jpg.rf.309d1f1435963f8d8f7543802e4452f2.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-121-_jpg.rf.ba6c0cbd1c3dbd3c627c3924b8e951d9.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-123-_jpg.rf.78ec294894147691c88cd28bce15fb53.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-126-_jpg.rf.4a139bb58649bd8ccd5a1a888efdc809.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-127-_jpg.rf.d0e0b0b792b4570d6f7ebd9bf2ba47b8.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-128-_jpg.rf.5f1ee1002f5ec1c250e5339b8dfb77f0.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-131-_jpg.rf.0ba72a4132a43686392c662c8f2d9544.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-133-_jpg.rf.1a8bbba53e9ea272b8e5bc230a23b7d1.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-134-_jpg.rf.93e9c8621503505743267b60a33356e4.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-135-_jpg.rf.dc19036763e7315898cda82e03ca83da.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-137-_jpg.rf.0cac64a7338f3b99df94b38aa89245c3.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-14-_jpg.rf.2ada7182d8b46e5e3fad10d9feccff79.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-141-_jpg.rf.1476668985f72c4bfad6ba254a956a84.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-142-_jpg.rf.3b108752a67a960cd7e172821001fdcb.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-144-_jpg.rf.a202269aa559937682560bc898e8ce2d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-145-_jpg.rf.4e39bb9b70e0361be8d41e8254b010ad.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-146-_jpg.rf.1c993de4ef8c86c854e87039bb8f7780.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1460-_jpg.rf.e80248a6a88c5b018c25cec892980771.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1465-_jpg.rf.2f7fd45ed2a1aad1231f6232a4800442.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-147-_jpg.rf.e1ddb0ed4c6a8fa9011a068181f281ba.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-151-_jpg.rf.eab5fe75822abc0677bee1c27544bee2.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-152-_jpg.rf.c827d3f7d4f7f6322019ed359f88ad5b.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-154-_jpg.rf.304674a90d52bacb9673151904ea99fc.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1548-_jpg.rf.cc39c4d357cc9335c56c39eceab46678.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-155-_jpg.rf.80979fadbb7cc4f95c9342e35d674f2f.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-158-_jpg.rf.8ab49ae61c679c086c828e718485cfc3.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-159-_jpg.rf.28de95cc798524d979ee7e9b553a2afd.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-16-_jpg.rf.800d9d42ff106e96688d8075779ff14b.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-165-_jpg.rf.ff326e1323dcaab6ad1208147b1c6576.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-168-_jpg.rf.4e9cae1127f0f747017b074378f48f8d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1683-_jpg.rf.7c4d22ae4528a081d842bd4b06fefbea.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-169-_jpg.rf.0f4fe471754545f117e4ff985830434d.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-173-_jpg.rf.79c4cb5882d4f50c581d1d7cd373edde.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1730-_jpg.rf.289c67e400939ed2a929875c9c9da007.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-174-_jpg.rf.968aace44904d07af801d98596d89868.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-177-_jpg.rf.f531f5cc3d37fbd0ea8b6f709eb07e3f.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-178-_jpg.rf.375565e4e446376a6c446fbe2f086cae.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-18-_jpg.rf.1103b632e9e6a376514c21be51402938.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1816-_jpg.rf.87a34ba6056a33f192fe846bed113643.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1818-_jpg.rf.50ad679c54f26babae162d127bdbb18e.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-187-_jpg.rf.fa0d5fe24efc801dbd85c0d29a0290b8.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-188-_jpg.rf.ac8fe21da850b882a70aeefeb1ff74de.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-189-_jpg.rf.56caf504c45a3424b4824744ffe094c9.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1935-_jpg.rf.d81f04a39549db20ba8e98553bfd2f2e.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1956-_jpg.rf.27f9268c41d377c5b217207a700481c4.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-196-_jpg.rf.93de951ceb07b288caa19a11a11d5f0a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-197-_jpg.rf.cf2b217d6cd1a4b955bec6f4c2bd3c6f.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-1971-_jpg.rf.0dfa3ec09ef70698bf39fc76c24da879.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-199-_jpg.rf.5d476a35c09459e0b6ba45cf3c4f314f.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-2-_jpg.rf.7f5496f9fc20f748d6790af6bb24e8f1.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-201-_jpg.rf.69bb9e511df8955a03e226485dfad9c3.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-2010-_jpg.rf.e3d006448357dfa8b93e91b1f25aaf6b.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-203-_jpg.rf.a5a60516a5fdcee32fd96a606e332e4a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-204-_jpg.rf.bfc4b85430ff3f8c9972926a29b508d4.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-207-_jpg.rf.c27d34f37f8226856387b8db9deb17d5.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-208-_jpg.rf.050bafe188f9c841f5041f1fc76aeb67.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-212-_jpg.rf.05bd91bfe60b840ec850a62608080bc9.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-217-_jpg.rf.1898633038bb6030a0bd5168fa909211.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-218-_jpg.rf.5ef418e03f6f424d450115d19e800d43.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-219-_jpg.rf.cd5e0fb315f4e82b5319176492cdef21.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-220-_jpg.rf.8f39c3cf46546bb2d173f62c3a40ac80.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-221-_jpg.rf.b790bd75ae97122438fbacb18f26cf9e.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-222-_jpg.rf.425dfd0e2f4d30a980ed40fbeb80b2c5.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-223-_jpg.rf.524ed0174168eebcbc24f2214ea25943.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-2273-_jpg.rf.159bde2d2b7b6ea4f91bbbd13573ef98.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-23-_jpg.rf.ed9bfea3e7234acd26fa486fa71ecbb8.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-231-_jpg.rf.e0341f8a21a2b5a207f4bc49f33a6013.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-232-_jpg.rf.0df147bda3952e70e05ea6232f3605de.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-233-_jpg.rf.12ae7669c04ab4e9843d681e390bbe0a.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-238-_jpg.rf.19798dcf3c2d80bad3d570f0e9b711b5.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-239-_jpg.rf.78ce4215e552083b3ae0d4731b99e197.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-24-_jpg.rf.3b81734804edb5974de444f7aed9e6c6.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-241-_jpg.rf.ae2e2345b29329f594f7e0e22d4ff454.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-249-_jpg.rf.6be511378ebcb89e96687320d83b3232.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-25-_jpg.rf.3ef4a6bdc27f8a515a145774ddc5cbca.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-250-_jpg.rf.051ecf22468c50cc0631e0b60a58dd74.jpg: ignoring corrupt image/label: Label class 1 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-251-_jpg.rf.d5e37f0655b42b7fc3a4495ed9d38f71.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-252-_jpg.rf.10e2aef2d5335f9a0194b35f2926a622.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# train: WARNING ⚠️ /content/data/train/images/large_-255-_jpg.rf.ad155d62039b7f20311d919a1ca482fe.jpg: ignoring corrupt image/label: Label class 2 exceeds dataset class count 1. Possible class labels are 0-0
# ...
#                    all        721       1034      0.562      0.314      0.397      0.161
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      65/100      3.63G      1.542      2.635      1.723          2        640: 100% 206/206 [00:54<00:00,  3.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  3.91it/s]
#                    all        721       1034      0.262       0.58      0.369      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      66/100      3.66G      1.492      2.621      1.701          2        640: 100% 206/206 [00:54<00:00,  3.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.03it/s]
#                    all        721       1034      0.628      0.284      0.408      0.168
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      67/100      3.67G      1.498      2.649      1.683          4        640: 100% 206/206 [00:54<00:00,  3.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.41it/s]
#                    all        721       1034      0.566      0.204       0.34      0.143
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      68/100      3.69G      1.503      2.643       1.68          3        640: 100% 206/206 [00:54<00:00,  3.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.60it/s]
#                    all        721       1034      0.529      0.307      0.376      0.158
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      69/100       3.7G      1.538      2.704      1.721          4        640: 100% 206/206 [00:54<00:00,  3.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.14it/s]
#                    all        721       1034       0.65      0.301      0.441      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      70/100      3.73G      1.481      2.705      1.686          2        640: 100% 206/206 [00:54<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.44it/s]
#                    all        721       1034      0.583      0.225      0.367      0.159
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      71/100      3.73G      1.459      2.551      1.633          3        640: 100% 206/206 [00:55<00:00,  3.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.52it/s]
#                    all        721       1034      0.583      0.231      0.377       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      72/100      3.76G      1.463      2.661      1.675          0        640: 100% 206/206 [00:55<00:00,  3.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  3.91it/s]
#                    all        721       1034      0.627      0.243      0.402      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      73/100      3.77G      1.478      2.556      1.691          1        640: 100% 206/206 [00:55<00:00,  3.70it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.07it/s]
#                    all        721       1034      0.621      0.275      0.395      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      74/100       3.8G        1.5      2.581      1.706          4        640: 100% 206/206 [00:54<00:00,  3.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.42it/s]
#                    all        721       1034      0.622      0.202      0.387       0.17
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      75/100       3.8G       1.46      2.766      1.687          4        640: 100% 206/206 [00:57<00:00,  3.56it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.38it/s]
#                    all        721       1034      0.567      0.299      0.358       0.16
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      76/100      3.83G      1.456      2.546       1.68          2        640: 100% 206/206 [00:55<00:00,  3.71it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.06it/s]
#                    all        721       1034      0.563      0.285      0.386      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      77/100      3.84G       1.46      2.603      1.668          1        640: 100% 206/206 [00:56<00:00,  3.65it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  3.99it/s]
#                    all        721       1034      0.593      0.309      0.413      0.181
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      78/100      3.86G       1.43      2.709      1.642          1        640: 100% 206/206 [00:54<00:00,  3.77it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.42it/s]
#                    all        721       1034      0.645      0.269      0.415       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      79/100      3.88G      1.457       2.54      1.659          2        640: 100% 206/206 [00:54<00:00,  3.80it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  3.91it/s]
#                    all        721       1034      0.572      0.227       0.38      0.166
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      80/100       3.9G      1.436      2.461      1.639          2        640: 100% 206/206 [00:55<00:00,  3.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.03it/s]
#                    all        721       1034      0.608       0.27       0.39      0.171
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      81/100      3.91G       1.46      2.606      1.657          1        640: 100% 206/206 [00:54<00:00,  3.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.48it/s]
#                    all        721       1034      0.601      0.225      0.395      0.172
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      82/100      3.93G      1.441       2.58      1.646          1        640: 100% 206/206 [00:54<00:00,  3.75it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.46it/s]
#                    all        721       1034      0.655       0.26      0.426      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      83/100      3.94G      1.424      2.526      1.621          4        640: 100% 206/206 [00:55<00:00,  3.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.16it/s]
#                    all        721       1034      0.598      0.272      0.392      0.173
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      84/100      3.96G      1.406      2.523      1.647          1        640: 100% 206/206 [00:55<00:00,  3.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.83it/s]
#                    all        721       1034      0.559      0.306      0.365      0.165
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      85/100      3.98G      1.403      2.566      1.624          1        640: 100% 206/206 [00:55<00:00,  3.72it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.42it/s]
#                    all        721       1034      0.567      0.235      0.379      0.163
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      86/100         4G      1.448      2.527      1.645          6        640: 100% 206/206 [00:54<00:00,  3.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.13it/s]
#                    all        721       1034      0.609      0.284      0.402      0.177
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      87/100      4.01G      1.455      2.533      1.655          2        640: 100% 206/206 [00:54<00:00,  3.76it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.83it/s]
#                    all        721       1034      0.633      0.257       0.42       0.19
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      88/100      4.03G      1.432      2.536      1.635          1        640: 100% 206/206 [00:54<00:00,  3.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.41it/s]
#                    all        721       1034      0.622      0.242      0.389      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      89/100      4.04G      1.437      2.444       1.65          7        640: 100% 206/206 [00:54<00:00,  3.78it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.08it/s]
#                    all        721       1034      0.624      0.284      0.407       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      90/100      4.07G      1.432      2.414      1.646          2        640: 100% 206/206 [00:55<00:00,  3.74it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  3.96it/s]
#                    all        721       1034       0.59      0.257      0.385       0.17
# Closing dataloader mosaic
# albumentations: Blur(p=0.01, blur_limit=(3, 7)), MedianBlur(p=0.01, blur_limit=(3, 7)), ToGray(p=0.01, num_output_channels=3, method='weighted_average'), CLAHE(p=0.01, clip_limit=(1.0, 4.0), tile_grid_size=(8, 8))
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      91/100      4.08G      1.388      2.919      1.685          1        640: 100% 206/206 [00:53<00:00,  3.82it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.55it/s]
#                    all        721       1034      0.538      0.324      0.382      0.175
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      92/100       4.1G      1.411      2.588      1.701          2        640: 100% 206/206 [00:52<00:00,  3.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  3.99it/s]
#                    all        721       1034      0.279      0.636      0.402      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      93/100      4.11G      1.395      2.562      1.692          5        640: 100% 206/206 [00:52<00:00,  3.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.46it/s]
#                    all        721       1034      0.559      0.412      0.417      0.188
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      94/100      4.13G      1.422      2.475      1.749          0        640: 100% 206/206 [00:52<00:00,  3.90it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  3.96it/s]
#                    all        721       1034      0.547      0.397      0.409      0.184
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      95/100      4.15G      1.334      2.642      1.641          6        640: 100% 206/206 [00:53<00:00,  3.88it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.42it/s]
#                    all        721       1034      0.135      0.761        0.4       0.18
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      96/100      4.17G      1.349      2.581       1.65          0        640: 100% 206/206 [00:52<00:00,  3.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.16it/s]
#                    all        721       1034      0.142       0.75        0.4      0.183
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      97/100      4.18G      1.328      2.546      1.617          0        640: 100% 206/206 [00:52<00:00,  3.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.45it/s]
#                    all        721       1034      0.155      0.736       0.41      0.186
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      98/100      4.21G      1.389      2.627      1.685          4        640: 100% 206/206 [00:52<00:00,  3.94it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  4.10it/s]
#                    all        721       1034       0.14      0.751      0.392      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#      99/100      4.21G      1.354      2.516      1.641          0        640: 100% 206/206 [00:52<00:00,  3.92it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:06<00:00,  3.40it/s]
#                    all        721       1034      0.136      0.751      0.391      0.178
#
#       Epoch    GPU_mem   box_loss   cls_loss   dfl_loss  Instances       Size
#     100/100      4.24G      1.301      2.547      1.629          1        640: 100% 206/206 [00:52<00:00,  3.91it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:05<00:00,  3.99it/s]
#                    all        721       1034      0.141      0.741      0.391      0.177
#
# 100 epochs completed in 1.716 hours.
# Optimizer stripped from runs/detect/train3/weights/last.pt, 6.3MB
# Optimizer stripped from runs/detect/train3/weights/best.pt, 6.3MB
#
# Validating runs/detect/train3/weights/best.pt...
# Ultralytics 8.3.96 🚀 Python-3.11.11 torch-2.6.0+cu124 CUDA:0 (Tesla T4, 15095MiB)
# Model summary (fused): 72 layers, 3,005,843 parameters, 0 gradients, 8.1 GFLOPs
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 23/23 [00:08<00:00,  2.74it/s]
#                    all        721       1034      0.652      0.302      0.441      0.188
# Speed: 0.3ms preprocess, 2.5ms inference, 0.0ms loss, 2.7ms postprocess per image
# Results saved to runs/detect/train3
# 💡 Learn more at https://docs.ultralytics.com/modes/train

# %% [markdown]
# The training algorithm will parse the images in the training and validation directories and then start training the model. At the end of each training epoch, the program runs the model on the validation dataset and reports the resulting mAP, precision, and recall. As training continues, the mAP should generally increase with each epoch. Training will end once it goes through the number of epochs specified by `epochs`.
#
# > **NOTE:** Make sure to allow training to run to completion, because an optimizer runs at the end of training that strips out unneeded layers from the model.
#
# The best trained model weights will be saved in `content/runs/detect/train/weights/best.pt`. Additional information about training is saved in the `content/runs/detect/train` folder, including a `results.png` file that shows how loss, precision, recall, and mAP progressed over each epoch.

# %% [markdown]
# #6.&nbsp;Test Model

# %% [markdown]
# The model has been trained; now it's time to test it! The commands below run the model on the images in the validation folder and then display the results for the first 10 images. This is a good way to confirm your model is working as expected. Click Play on the blocks below to see how your model performs.

# %%
# !yolo detect predict model=runs/detect/train/weights/best.pt source=data/validation/images save=True

# %%
import glob
from IPython.display import Image, display
for image_path in glob.glob(f'/content/runs/detect/predict/*.jpg')[:10]:
  display(Image(filename=image_path, height=400))
  print('\n')

# %% [markdown]
# The model should draw a box around each object of interest in each image. If it isn't doing a good job of detecting objects, here are a few tips:
#
# 1. Double-check your dataset to make sure there are no labeling errors or conflicting examples.
# 2. Increase the number of epochs used for training.
# 3. Use a larger model size (e.g. `yolo11l.pt`).
# 4. Add more images to the training dataset. See my [dataset video](https://www.youtube.com/watch?v=v0ssiOY6cfg) for tips on how to capture good training images and improve accuracy.
#
# You can also run the model on video files or other images images by uploading them to this notebook and using the above `!yolo detect predict` command, where `source` points to the location of the video file, image, or folder of images. The results will be saved in `runs/detect/predict`.
#
# Drawing boxes on images is great, but it isn't very useful in itself. It's also not very helpful to just run this models inside a Colab notebook: it's easier if we can just run it on a local computer. Continue to the next section to see how to download your newly trained model and run it on a local device.

# %% [markdown]
# #7.&nbsp;Deploy Model

# %% [markdown]
# Now that your custom model has been trained, it's ready to be downloaded and deployed in an application! YOLO models can run on a wide variety of hardware, including PCs, embedded systems, and phones. Ultralytics makes it easy to convert the YOLO models to various formats (`tflite`, `onnx`, etc.) and deploy them in a variety of environments.
#
# This section shows how to download the model and provides links to instructions for deploying it on your PC and edge devices like the Raspberry Pi.

# %% [markdown]
# ## 7.1 Download YOLO Model
#
# First, zip and download the trained model by running the code blocks below.
#
# The code creates a folder named `my_model`, moves the model weights into it, and renames them from `best.pt` to `my_model.pt`. It also adds the training results in case you want to reference them later. It then zips the folder as `my_model.zip`.

# %%
# Create "my_model" folder to store model weights and train results
# !mkdir /content/my_model
# !cp /content/runs/detect/train/weights/best.pt /content/my_model/my_model.pt
# !cp -r /content/runs/detect/train /content/my_model

# Zip into "my_model.zip"
# %cd my_model
# !zip /content/my_model.zip my_model.pt
# !zip -r /content/my_model.zip train
# %cd /content

# %%
# This takes forever for some reason, you can also just download the model from the sidebar
from google.colab import files

files.download('/content/my_model.zip')

# %% [markdown]
# ## 7.2 Deploy YOLO Model on Local Devices
#
# Next, we'll take our downloaded model and run it on a local device. This section provides instructions showing how to deploy YOLO models on various devices.
#
# I wrote a basic Python script, `yolo_detect.py`, that shows how to load a model, run inference on an image source, parse the inference results, and display boxes around each detected class in the image. The [script](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/yolo_detect.py) gives an example of how to work with Ultralytics YOLO models in Python, and it can be used as a starting point for more advanced applications.

# %% [markdown]
# ### 7.2.1 Deploy on PC (Windows, Linux, or macOS)
#
# The easiest way to run Ultralytics models on a PC is using Anaconda. Anaconda sets up a virtual Python environment and allows you to easily install Ultralytics and PyTorch. It automatically installs CUDA and cuDNN, which allows you to speed up model inference with your NVIDIA GPU.
#
# > **NOTE:** My YouTube video (link to be added) shows how to deploy your model on a PC. It walks through the following steps, so watch the video if you prefer having visual instructions.
#
# **1. Download and Install Anaconda**
#
# Go to the Anaconda download page at https://anaconda.com/download, click the “skip registration” button, and then download the package for your OS. When it's finished downloading, run the installer and click through the installation steps. You can use the default options for installation.
#
# **2. Set up virtual environment**
#
# Once it's installed, run Anaconda Prompt from the Start Bar. (If you're on macOS or Linux, just open a command terminal).
#
# Issue the following commands to create a new Python environment and activate it:
#
# ```
# conda create --name yolo-env1 python=3.12 -y
# conda activate yolo-env1
# ```
#
# Install Ultralytics (which also installs import libraries like OpenCV-Python, Numpy, and PyTorch) by issuing the following command:
#
# ```
# pip install ultralytics
# ```
#
# If you have an NVIDIA GPU, you can install the GPU-enabled version of PyTorch by issuing the following command:
#
# ```
# pip install --upgrade torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu124
# ```
#
# **3. Extract downloaded model**
# Take the `my_model.zip` file you downloaded in Step 7.1 and unzip it to a folder on your PC. In the Anaconda Prompt terminal, move into the unzipped folder using:
#
# ```
# cd path/to/folder
# ```
#
# **4. Download and run yolo_detect.py**
#
# Download the `yolo_detect.py` script into the `my_model` folder using:
#
# ```
# curl -o yolo_detect.py https://raw.githubusercontent.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/refs/heads/main/yolo_detect.py
# ```
#
# Alright! We're ready to run the script. To run inference with a yolov8s model on a USB camera at 1280x720 resolution, issue:
#
# ```
# python yolo_detect.py --model my_model.pt --source usb0 --resolution 1280x720
# ```
#
# A window will appear showing a live feed from your webcam with boxes drawn around detected objects in each frame.
#
# You can also run the model on an video file, image, or folder of images. To see a full list of arguments for `yolo_detect.py`, issue `python yolo_detect.py --help` or see the [README file](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/blob/main/README.md).

# %% [markdown]
# ### 7.2.2 Deploy on Raspberry Pi
#
# Keep an eye out for an article showing how to convert YOLO models to NCNN format and run them on the Raspberry Pi!

# %% [markdown]
# # 8.&nbsp;Conclusion

# %% [markdown]
# Congratulations! You've successfully trained and deployed a YOLO object detection model. 😀
#
# Next, you can extend your application beyond just drawing boxes and counting objects. Add functionality like logging the number of objects detected over time or taking a picture when certain objects are detected. Check out some example applications at our GitHub repository: https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models
#
# Thanks for working through this notebook, and good luck with your projects!

# %% [markdown]
# # Appendix: Common Errors

# %% [markdown]
# If you run into any errors working through this notebook, please do the following:
#
#
# - Double-check that the dataset files are set up in the correct folder structure
# - Make sure there are no typos or errors in your labelmap file
# - Google search the error to look for solutions
#
# If none of those help, please submit an [Issue](https://github.com/EdjeElectronics/Train-and-Deploy-YOLO-Models/issues) on the GitHub page. In this section, I will add resolutions to common errors as they come up.
